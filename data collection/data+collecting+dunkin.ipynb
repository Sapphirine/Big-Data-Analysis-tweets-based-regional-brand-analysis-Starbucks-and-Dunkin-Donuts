# %%
import tweepy
import json

consumer_key = "s1C1uTNAADrUWhPeNfwsGBkla"
consumer_secret = "Vg4Crx78uaE3EBMwenG9Qkx3MMm0HUoh7KHvPznQU8Ynh6HVre" 
access_key = "1050589114385555456-4o0z9Coaga4lgLJp3lWeqA8egh9t5Q" 
access_secret = "TTVKc0Q2SjSYzW08C08lNMVJuI11dpDGkTV8rP3avxOTy"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth_handler=auth, wait_on_rate_limit=True)

r = 'Texas'
c = 0
tweets = []
txt = []
places = api.geo_search(query=r)
place_id = places[0].id
print(places[0].id)
last_id=''
while c <= 2000:
    if last_id=='':
        public_tweets = api.search(q="place:%s AND dunkin" % place_id)
        if len(public_tweets)==0:
            print("no tweets")
        else:
            last_id=public_tweets[-1].id
    else:
        public_tweets = api.search(q="place:%s AND dunkin" % place_id, count=100, max_id=last_id)
        if len(public_tweets)==0:
            print("no tweets")
        else:
            last_id=public_tweets[-1].id
    for tweet in public_tweets:
        if tweet.text not in txt:
            print('\n')
            tweet1 = {}
            tweet1['location'] = r
            tweet1['text'] = tweet.text
            print(tweet.user.location)
            print(tweet.text)
            c = c+1
            tweet1['index'] = c
            print(c)
            txt.append(tweet.text)
            tweets.append(tweet1)
# Out:
# e0060cda70f5f341
#
#
# South FL ✈ College Station
# I had Dunkin Donuts Iced Coffee today so anything is possible!!!
# 1
#
#
# houston
# Texans are in trouble. They refuse to to blitz more than 3 guys every damn play. They keep playing zone and Colts keep dinkin and Dunkin
# 2
#
#
# Austin, TX
# I want a kolache and donuts but the only place close to here is stupid Dunkin’ Donuts 😔😔
# 3
#
#
#
# maple frosted donut from dunkin
# 4
#
#
# Houston
# Drinking a Dunkin’ Coffee Porter by @harpoonbrewery @ Texans Tailgate Orange Lot — https://t.co/7tRs8iXakX
# 5
#
#
# Austin, TX
# I'm at Dunkin Donuts in Dripping Springs, TX https://t.co/wwRdgo4ZiW
# 6
#
#
# Los Angeles, CA
# Mama and I waitin’ for the film to start. #astarisborn #family #motherdaughter #plantbased #plantbasedliving… https://t.co/R6m4X17Ddg
# 7
#
#
# Austin, TX
# Dunkin Donuts has branched out a bit 🤣 @ Total Wine &amp; More https://t.co/JdiuH8uUw0
# 8
#
#
# Jersey ✈Dallas
# Dunkin Donuts’ donuts are nasty as hell.
# 9
#
#
# ...

# %%
import csv
with open('tweet_dunkin/Texas.csv', 'a') as dstfile: 
    fieldnames = ['index','location','text']
    writer = csv.DictWriter(dstfile,fieldnames)
    writer.writeheader()
    writer.writerows(tweets)
dstfile.close()
